# %%
import pandas as pd

# Load processed CM1 training data
train_data = pd.read_csv('../data/processed/cm1_train.csv')

print("✅ Processed CM1 Training Data")
print("="*80)
print(f"Shape: {train_data.shape}")
print(f"\nFirst few rows:")
print(train_data.head())
print(f"\nTarget distribution:")
print(train_data['target'].value_counts())
print(f"\nFeature statistics (first 5 features):")
print(train_data.iloc[:, :5].describe())
# Out:
# ✅ Processed CM1 Training Data
# ...
# Shape: (353, 22)
#
# First few rows:
#         loc      v(g)     ev(g)     iv(g)         n         v         l  \
# 0 -0.028882 -0.008803 -0.423712  0.344811 -0.160424 -0.183063 -0.346258
# 1 -0.258178 -0.220192  0.328654  0.019187 -0.270421 -0.285255 -0.214119
# 2  0.054498 -0.008803 -0.423712  0.344811  0.079941 -0.015839 -0.544467
# 3 -0.570854 -0.537276 -0.423712 -0.469249 -0.518934 -0.468770  0.116230
# 4 -0.383248 -0.431581 -0.423712 -0.469249 -0.498564 -0.447579 -0.280188
#
#           d         i         e  ...    lOCode  lOComment   lOBlank  \
# 0 -0.258288  0.298619 -0.214513  ...  0.052154   1.015889  1.319814
# 1 -0.406556  0.135717 -0.238010  ... -0.157056  -0.244539 -0.261020
# 2  0.273368  0.134192 -0.133326  ...  0.470575   0.266445  0.100314
# 3 -0.639195 -0.517671 -0.264839  ...  0.156760  -0.482999 -0.396520
# 4 -0.397871 -0.618056 -0.258554  ... -0.470872  -0.244539 -0.261020
#
# ...
